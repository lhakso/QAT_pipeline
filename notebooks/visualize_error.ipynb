# %%
import pandas as pd

# %%
df = pd.read_json("../grace/eval_data/flipped_FP32.jsonl", lines=True)

# %%
df[(df['baseline_correct'] == False) & (df['edited_correct'] == True)]
# Out:
#                                                  text  label  baseline_pred  \
# 0   ( d ) oes n ' t bother being as cloying or pre...      1              0
# 1    ... routine, harmless diversion and little else.      1              0
# 2   ... mafia, rap stars and hood rats butt their ...      1              0
# 3   a full world has been presented onscreen, not ...      1              0
# 4   a movie that successfully crushes a best selli...      1              0
# ..                                                ...    ...            ...
# 72                    holden caulfield did it better.      0              1
# 73  vera ' s technical prowess ends up selling his...      0              1
# 74  jaglom... put ( s ) the audience in the privil...      1              0
# 76  intriguing documentary which is emotionally di...      1              0
# 78                  hilariously inept and ridiculous.      1              0
#
# ...

# %%
df[df['quant_correct'] == False]
# Out:
#                                                  text  label  baseline_pred  \
# 37  all that ' s missing is the spontaneity, origi...      0              0
# 63  turns potentially forgettable formula into som...      1              1
# 75  huston nails both the glad - handing and the c...      1              1
# 77  pumpkin means to be an outrageous dark satire ...      0              0
#
#                                baseline_probs  baseline_correct  edited_pred  \
# 37  [0.5413330793380731, 0.45866689085960305]              True            0
# 63  [0.47368463873863204, 0.5263153910636901]              True            1
# 75     [0.373344540596008, 0.626655459403991]              True            1
# 77     [0.504752814769744, 0.495247155427932]              True            0
#
#                                  edited_probs  edited_correct  quant_pred  \
# 37  [0.5413330793380731, 0.45866689085960305]            True           1
# ...

# %%
df[df['transition']=='0->1->1']
# Out:
#                                                  text  label  baseline_pred  \
# 0   ( d ) oes n ' t bother being as cloying or pre...      1              0
# 1    ... routine, harmless diversion and little else.      1              0
# 2   ... mafia, rap stars and hood rats butt their ...      1              0
# 3   a full world has been presented onscreen, not ...      1              0
# 4   a movie that successfully crushes a best selli...      1              0
# ..                                                ...    ...            ...
# 72                    holden caulfield did it better.      0              1
# 73  vera ' s technical prowess ends up selling his...      0              1
# 74  jaglom... put ( s ) the audience in the privil...      1              0
# 76  intriguing documentary which is emotionally di...      1              0
# 78                  hilariously inept and ridiculous.      1              0
#
# ...
